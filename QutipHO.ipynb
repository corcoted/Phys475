# %%
import numpy as np
import matplotlib.pyplot as plt
from qutip import *

# %%
ndim = 10 # maximum dimension

# %%
H = (momentum(ndim)*momentum(ndim) + position(ndim)*position(ndim))/2

# %%
KE = (momentum(ndim)*momentum(ndim))/2

# %%
KE
# Out:
# Quantum object: dims = [[10], [10]], shape = (10, 10), type = oper, isherm = True
# Qobj data =
# [[ 0.25        0.         -0.35355339  0.          0.          0.
#    0.          0.          0.          0.        ]
#  [ 0.          0.75        0.         -0.61237244  0.          0.
#    0.          0.          0.          0.        ]
#  [-0.35355339  0.          1.25        0.         -0.8660254   0.
#    0.          0.          0.          0.        ]
#  [ 0.         -0.61237244  0.          1.75        0.         -1.11803399
#    0.          0.          0.          0.        ]
#  [ 0.          0.         -0.8660254   0.          2.25        0.
#   -1.36930639  0.          0.          0.        ]
#  [ 0.          0.          0.         -1.11803399  0.          2.75
#    0.         -1.62018517  0.          0.        ]
#  [ 0.          0.          0.          0.         -1.36930639  0.
#    3.25        0.         -1.87082869  0.        ]
# ...

# %%
V = (-position(ndim)*position(ndim)).expm()

# %%
V
# Out:
# Quantum object: dims = [[10], [10]], shape = (10, 10), type = oper, isherm = True
# Qobj data =
# [[ 0.70709096  0.         -0.24984148  0.          0.10754314  0.
#   -0.04722465  0.          0.01779105  0.        ]
#  [ 0.          0.35376175  0.         -0.21765186  0.          0.12479747
#    0.         -0.074624    0.          0.05337314]
#  [-0.24984148  0.          0.26385835  0.         -0.18652857  0.
#    0.10993971  0.         -0.04860663  0.        ]
#  [ 0.         -0.21765186  0.          0.22618571  0.         -0.18722582
#    0.          0.14949163  0.         -0.12776814]
#  [ 0.10754314  0.         -0.18652857  0.          0.17839936  0.
#   -0.12675561  0.          0.06185546  0.        ]
#  [ 0.          0.12479747  0.         -0.18722582  0.          0.20700541
#    0.         -0.20544699  0.          0.19726711]
#  [-0.04722465  0.          0.10993971  0.         -0.12675561  0.
#    0.10080882  0.         -0.05209392  0.        ]
# ...

# %%
H = KE+V

# %%
H
# Out:
# Quantum object: dims = [[10], [10]], shape = (10, 10), type = oper, isherm = True
# Qobj data =
# [[ 0.95709096  0.         -0.60339487  0.          0.10754314  0.
#   -0.04722465  0.          0.01779105  0.        ]
#  [ 0.          1.10376175  0.         -0.8300243   0.          0.12479747
#    0.         -0.074624    0.          0.05337314]
#  [-0.60339487  0.          1.51385835  0.         -1.05255397  0.
#    0.10993971  0.         -0.04860663  0.        ]
#  [ 0.         -0.8300243   0.          1.97618571  0.         -1.30525981
#    0.          0.14949163  0.         -0.12776814]
#  [ 0.10754314  0.         -1.05255397  0.          2.42839936  0.
#   -1.496062    0.          0.06185546  0.        ]
#  [ 0.          0.12479747  0.         -1.30525981  0.          2.95700541
#    0.         -1.82563216  0.          0.19726711]
#  [-0.04722465  0.          0.10993971  0.         -1.496062    0.
#    3.35080882  0.         -1.92292261  0.        ]
# ...

# %%
H.eigenenergies()
# Out:
# array([0.08589071, 0.25993903, 0.66043137, 0.87750583, 1.76366732,
#        1.81350284, 3.40933013, 3.46049377, 6.11640591, 6.60852785])

# %%
H.eigenstates()
# Out:
# (array([0.08589071, 0.25993903, 0.66043137, 0.87750583, 1.76366732,
#         1.81350284, 3.40933013, 3.46049377, 6.11640591, 6.60852785]),
#  array([Quantum object: dims = [[10], [1]], shape = (10, 1), type = ket
#  Qobj data =
#  [[ 0.        ]
#   [-0.33532063]
#   [ 0.        ]
#   [-0.46825022]
#   [ 0.        ]
#   [-0.47620004]
#   [ 0.        ]
#   [-0.48600837]
#   [ 0.        ]
#   [-0.45313485]],
#         Quantum object: dims = [[10], [1]], shape = (10, 1), type = ket
#  Qobj data =
#  [[0.48458467]
#   [0.        ]
#   [0.62784656]
#   [0.        ]
#   [0.49653783]
#   [0.        ]
#   [0.31903972]
#   [0.        ]
#   [0.15049996]
#   [0.        ]],
#         Quantum object: dims = [[10], [1]], shape = (10, 1), type = ket
#  Qobj data =
#  [[ 0.        ]
#   [-0.7187516 ]
#   [ 0.        ]
#   [-0.37618865]
#   [ 0.        ]
#   [ 0.07521319]
#   [ 0.        ]
#   [ 0.3632776 ]
#   [ 0.        ]
#   [ 0.45194092]],
# ...
